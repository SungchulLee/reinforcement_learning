# %%
import retro
retro.data.list_games()
# Out:
# ['1942-Nes',
#  '1943-Nes',
#  '3NinjasKickBack-Genesis',
#  '8Eyes-Nes',
#  'AaahhRealMonsters-Genesis',
#  'AbadoxTheDeadlyInnerWar-Nes',
#  'AcceleBrid-Snes',
#  'ActRaiser2-Snes',
#  'ActionPachio-Snes',
#  'AddamsFamily-GameBoy',
#  'AddamsFamily-Genesis',
#  'AddamsFamily-Nes',
#  'AddamsFamily-Sms',
#  'AddamsFamily-Snes',
#  'AddamsFamilyPugsleysScavengerHunt-Nes',
#  'AddamsFamilyPugsleysScavengerHunt-Snes',
#  'AdvancedBusterhawkGleylancer-Genesis',
#  'Adventure-Atari2600',
#  'AdventureIsland-GameBoy',
#  'AdventureIsland3-Nes',
#  'AdventureIslandII-Nes',
#  'AdventuresOfBatmanAndRobin-Genesis',
#  'AdventuresOfBayouBilly-Nes',
#  'AdventuresOfDinoRiki-Nes',
#  'AdventuresOfDrFranken-Snes',
#  'AdventuresOfKidKleets-Snes',
#  'AdventuresOfMightyMax-Genesis',
#  'AdventuresOfMightyMax-Snes',
#  'AdventuresOfRockyAndBullwinkleAndFriends-Genesis',
#  'AdventuresOfRockyAndBullwinkleAndFriends-Nes',
#  'AdventuresOfRockyAndBullwinkleAndFriends-Snes',
# ...

# %%
import retro

if 0: # 한상준
    env = retro.make(game='Adventure-Atari2600')
elif 0: # 오탁근, 2017314009
    env = retro.make(game='AirRaid-Atari2600')
elif 0: # 김태현, 김상균, 김예진, 이민현, 정승우, 엄준식, 조영찬, 김상균, 
    # Mohammad, 2016324106, 2018311378, 20190319
    env = retro.make(game='Airstriker-Genesis')
elif 0: # 2018311378, 정호제, 정승우
    env = retro.make(game='Airstriker-Genesis', state='Level1')
elif 1: # 김현빈, 한상준
    env = retro.make(game='Alien-Atari2600')
elif 1:
    env = retro.make(game='Amidar-Atari2600')
elif 1: # 오탁근
    env = retro.make(game='Bowling-Atari2600') 
elif 1: # 오탁근
    env = retro.make(game='Boxing-Atari2600') 
elif 1: # 한상준
    env = retro.make(game='Breakout-Atari2600')
elif 0:
    env = retro.make(game='ChopperCommand-Atari2600')
elif 0: # 김현빈
    env = retro.make(game='CrazyClimber-Atari2600')
elif 0:
    env = retro.make('DemonAttack-Atari2600', 'Start')
elif 0: # 한상준
    env = retro.make(game='DoubleDunk-Atari2600')
elif 0: # 오탁근
    env = retro.make(game='FishingDerby-Atari2600')
elif 0: # 기호연
    env = retro.make(game='fishingderby-atari2600', state='Start')
elif 0: # 오탁근
    env = retro.make(game='Freeway-Atari2600') 
elif 0: # 홍석우
    env = retro.make(game='Kaboom-Atari2600') 
elif 0: # 조일형
    env = retro.make(game='Krull-Atari2600')
elif 0: # 정유진
    env = retro.make(game='KungFuMaster-Atari2600')
elif 0:
    env = retro.make(game='NameThisGame-Atari2600')
elif 0: # 권세진
    env = retro.make(game='phoenix-atari2600')
elif 0: # 김현균
    env = retro.make(game='Pooyan-Atari2600') 
elif 1: # 2017314016, 2018314396
    env = retro.make(game='Skiing-Atari2600')
elif 0: # 한상준
    env = retro.make(game='StarGunner-Atari2600')
elif 0: # 오탁근, 김현빈
    env = retro.make(game='Tennis-Atari2600') 
elif 1:
    env = retro.make(game='Tutankham-Atari2600')
elif 0: # 오탁근
    env = retro.make(game='VideoPinball-Atari2600') 
    
env.reset()
done = False
while not done:
    env.render()
    action = env.action_space.sample()
    next_state, reward, done, info = env.step(action)
        
    if done:
        # env.render() # OpenAi_Gym
        env.render(close=True) # Retro_Gym 
        env.close()
