# %% [markdown]
# # Iterative Policy Evaluation

# %% [markdown]
# <a href="#1-Iterative-Policy-Evaluation-for-V">1 Iterative Policy Evaluation for V</a>
#
# <a href="#2-Iterative-Policy-Evaluation-for-Q">2 Iterative Policy Evaluation for Q</a>

# %% [markdown]
# Sutton
# [pdf](http://localhost:8888/notebooks/Dropbox/Paper/bookdraft2017nov5.pdf)
# Szepesvári
# [pdf](http://localhost:8888/notebooks/Dropbox/Paper/Algorithms-for-Reinforcement-Learning.pdf)
# Ng
# [16](https://www.youtube.com/watch?v=RtxI449ZjSc&list=PLA89DCFA6ADACE599&index=16)
# [demo](http://heli.stanford.edu/)
# Silver
# [3](https://www.youtube.com/watch?v=Nd1-UUMVfz4&index=3&list=PL7-jPKtc4r78-wCZcQn5IqyuWhBZ8fOxT)
# [pdf](http://localhost:8888/notebooks/Dropbox/Paper/Reinforcement_Learning_by_David_Silver_3.pdf)

# %% [markdown]
# # 1 Iterative Policy Evaluation for V

# %% [markdown]
# For deterministic policy $\pi$ and action-independent reward $R$
# $$V^{\pi}(s)=R(s)+\gamma\sum_{s'}P(s,\pi(s),s')V^{\pi}(s')$$
#
# For non-deterministic policy $\pi$ and action-independent reward $R$ (this is implemented)
# $$V^{\pi}(s)=\sum_{a}\pi(s)\left[R(s)+\gamma\sum_{s'}P(s,a,s')V^{\pi}(s')\right]$$
#
# For deterministic policy $\pi$ and action-dependent reward $R$
# $$V^{\pi}(s)=R(s,\pi(s))+\gamma\sum_{s'}P(s,\pi(s),s')V^{\pi}(s')$$
#
# For non-deterministic policy and $\pi$ action-dependent reward $R$
# $$V^{\pi}(s)=\sum_{a}\pi(s,a)\left[R(s,a)+\gamma\sum_{s'}P(s,a,s')V^{\pi}(s')\right]$$

# %%
from dqn_policy import POLICY
from model_MDP import IPE_V


" Policy "
policy = POLICY(policy_choice='random')
print(policy.policy)
print()


" Iterative_Policy_Evaluation for V "
ipe = IPE_V(policy.policy, num_iteration=500)
ipe.run_ipe()
print(ipe.V)
print()


" Plot of V_history "
ipe.plot()
# Out:
# [[0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]]
#
# [-0.48819026 -0.27323376  0.01149107  1.         -0.64206355 -0.61102065
#  -1.         -0.74107071 -0.78921204 -0.78843264 -0.91611303]

# %% [markdown]
# [<a href="#Iterative-Policy-Evaluation">Back to top</a>]

# %% [markdown]
# # 2 Iterative Policy Evaluation for Q

# %% [markdown]
# For deterministic policy $\pi$ and action-independent reward $R$
# \begin{array}{lll}
# Q^{\pi}(s,a)&=&R(s)+\gamma\sum_{s'}P(s,a,s')V^{\pi}(s')\\
# &=&R(s)+\gamma\sum_{s'}P(s,a,s')Q^{\pi}(s',\pi(s'))
# \end{array}
#
# For non-deterministic policy $\pi$ and action-independent reward $R$ (this is implemented)
# \begin{array}{lll}
# Q^{\pi}(s,a)&=&R(s)+\gamma\sum_{s'}P(s,a,s')V^{\pi}(s')\\
# &=&R(s)+\gamma\sum_{s'}P(s,a,s')\sum_{a'}\pi(s',a')Q^{\pi}(s',a')
# \end{array}
#
# For deterministic policy $\pi$ and action-dependent reward $R$
# \begin{array}{lll}
# Q^{\pi}(s,a)&=&R(s,a)+\gamma\sum_{s'}P(s,a,s')V^{\pi}(s')\\
# &=&R(s,a)+\gamma\sum_{s'}P(s,a,s')Q^{\pi}(s',\pi(s'))
# \end{array}
#
# For non-deterministic policy $\pi$ and action-dependent reward $R$
# \begin{array}{lll}
# Q^{\pi}(s,a)&=&R(s,a)+\gamma\sum_{s'}P(s,a,s')V^{\pi}(s')\\
# &=&R(s,a)+\gamma\sum_{s'}P(s,a,s')\sum_{a'}\pi(s',a')Q^{\pi}(s',a')
# \end{array}

# %%
from dqn_policy import POLICY
from model_MDP import IPE_Q


" Policy "
policy = POLICY(policy_choice='random')
print(policy.policy)
print()


" Iterative_Policy_Evaluation for Q "
ipe = IPE_Q(policy.policy, num_iteration=500)
ipe.run_ipe()
print(ipe.Q)
print()


" Plot of Q_history "
ipe.plot()
# Out:
# [[0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]
#  [0.25 0.25 0.25 0.25]]
#
# [[-0.51854182 -0.34829627 -0.48202767 -0.60389531]
#  [-0.46074697 -0.06499935 -0.28359436 -0.28359436]
#  [-0.29575457  0.71264657  0.06105079 -0.4319785 ]
#  [ 1.          1.          1.          1.        ]
#  [-0.65021116 -0.65021116 -0.53377527 -0.73405658]
#  [-0.58084557 -0.88891722 -0.17039011 -0.8039297 ]
#  [-1.         -1.         -1.         -1.        ]
#  [-0.74385829 -0.78198623 -0.68001232 -0.75842599]
#  [-0.76319198 -0.80070264 -0.79647677 -0.79647677]
#  [-0.78360181 -0.88410739 -0.67275554 -0.81326584]
#  [-0.83413384 -0.93525671 -0.98075002 -0.91431154]]

# %% [markdown]
# [<a href="#Iterative-Policy-Evaluation">Back to top</a>]
